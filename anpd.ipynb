# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3
import time
import re

import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
DATABASE_NAME = "internet_governance_news.db"

def create_database():
    conn = sqlite3.connect(DATABASE_NAME)
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS articles (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT,
            date TEXT,
            author TEXT,
            url TEXT UNIQUE,
            source TEXT
        )
    """)
    conn.commit()
    conn.close()
    print("✅ Banco e tabela 'articles' prontos!")

create_database()
# Out:
# ✅ Banco e tabela 'articles' prontos!

# %%
def insert_article(title, date, author, url, source):
    conn = sqlite3.connect(DATABASE_NAME)
    cursor = conn.cursor()
    try:
        cursor.execute("""
            INSERT INTO articles (title, date, author, url, source)
            VALUES (?, ?, ?, ?, ?)
        """, (title, date, author, url, source))
        conn.commit()
        return True
    except sqlite3.IntegrityError:
        return False
    finally:
        conn.close()

# %%
def montar_url(pagina):
    if pagina == 1:
        return "https://www12.senado.leg.br/noticias/ultimas"
    return f"https://www12.senado.leg.br/noticias/ultimas/{pagina}"

# %%
noticias = []

for pagina in range(5, 0, -1):
    url = montar_url(pagina)
    print(f"📄 Coletando página {pagina}: {url}")

    r = requests.get(url, timeout=10)
    soup = BeautifulSoup(r.text, "html.parser")

    lista = soup.find("ol", class_="lista-resultados")
    if not lista:
        print("⚠️ Nenhuma lista encontrada")
        continue

    itens = lista.find_all("li")
    print(f"   {len(itens)} notícias encontradas")

    for item in itens:
        titulo_tag = item.find("span", class_="eta")
        link_tag = item.find("a")
        data_tag = item.select_one("div.text-muted.normalis")

        if not titulo_tag or not link_tag:
            continue

        data = {
            "title": titulo_tag.get_text(strip=True),
            "date": data_tag.get_text(strip=True) if data_tag else None,
            "author": "Agência Senado",
            "url": "https://www12.senado.leg.br" + link_tag["href"],
            "source": "Senado Federal"
        }

        noticias.append(data)
        insert_article(**data)

    time.sleep(1)

print(f"\n✅ Total coletado: {len(noticias)} notícias")
df_senado = pd.DataFrame(noticias)
display(df_senado.head())
# Out:
# 📄 Coletando página 5: https://www12.senado.leg.br/noticias/ultimas/5
#    20 notícias encontradas
# 📄 Coletando página 4: https://www12.senado.leg.br/noticias/ultimas/4
#    20 notícias encontradas
# 📄 Coletando página 3: https://www12.senado.leg.br/noticias/ultimas/3
#    20 notícias encontradas
# 📄 Coletando página 2: https://www12.senado.leg.br/noticias/ultimas/2
#    20 notícias encontradas
# 📄 Coletando página 1: https://www12.senado.leg.br/noticias/ultimas
#    20 notícias encontradas
#
# ✅ Total coletado: 97 notícias
#                                                title              date  \
# 0  Para advogados, proposta de Código Civil pode ...  11/12/2025 16h11
# 1  Aprovado na Câmara, projeto do devedor contuma...  11/12/2025 15h55
# 2  Girão aponta conflito de interesses de Toffoli...  11/12/2025 15h16
# 3   Marco do Sistema de Pagamentos Brasileiro avança  11/12/2025 15h14
# 4  PL da Dosimetria será analisado na CCJ na quar...  11/12/2025 14h51
#
#            author                                                url  \
# 0  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
# 1  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
# 2  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
# 3  Agência Senado  https://www12.senado.leg.br/noticias/audios/20...
# 4  Agência Senado  https://www12.senado.leg.br/noticias/materias/...
#
#            source
# 0  Senado Federal
# 1  Senado Federal
# 2  Senado Federal
# 3  Senado Federal
# 4  Senado Federal

# %%
def load_articles():
    conn = sqlite3.connect(DATABASE_NAME)
    df = pd.read_sql("""
        SELECT * FROM articles
        ORDER BY date DESC
    """, conn)
    conn.close()
    return df

df_db = load_articles()
print(f"📦 Total no banco: {len(df_db)} registros")
display(df_db.head(20))
# Out:
# 📦 Total no banco: 609 registros
#      id                                              title         date  \
# 0    74  Em duas décadas, proporção de lares urbanos br...  31 OUT 2024
# 1   188  No FIB13, especialistas apontam expectativas e...  31 MAI 2023
# 2    12  Mais acessível e completo: conheça o novo site...  30 SET 2025
# 3    13  Evento em São Paulo celebra 15 anos de SACI-Ad...  30 SET 2025
# 4   189  Abertas as inscrições para o 13º Fórum da Inte...  30 MAI 2023
# 5   119  Declaração final do NETmundial+10 apresenta re...  30 ABR 2024
# 6    83               Nota de falecimento: Mariana Stanton  29 SET 2024
# 7   159        Nota de falecimento: Luiz Gonzaga Lauschner  29 SET 2023
# 8    38  Fórum da Internet no Brasil resgata legado da ...  29 MAI 2025
# 9    39  Prêmio Destaques homenageia 12 personalidades ...  29 MAI 2025
# 10   90  Escola de Governança da Internet no Brasil abr...  29 AGO 2024
# 11   91  Especialistas internacionais destacam os 20 an...  29 AGO 2024
# 12   92   NIC.br abre chamada de trabalhos para o IX Fórum  29 AGO 2024
# 13   46  IX.br atinge novo recorde, com 40 Tbit/s de tr...  29 ABR 2025
# 14  120  Ministra da Ciência, Tecnologia e Inovação ref...  29 ABR 2024
# 15   40  Com modelo multissetorial pioneiro e inovador,...  28 MAI 2025
# 16   41  CGI.br lança proposta de princípios para a reg...  27 MAI 2025
# 17  111  Uso mais planejado, estratégico e regulado da ...  27 MAI 2024
# 18   93  Fascículo Redes do CERT.br traz orientações de...  27 AGO 2024
# 19  160  Hartmut Glaser e Ivan Moura Campos entram para...  26 SET 2023
#
#              author                                                url  \
# 0   CGI.br Notícias  https://cgi.br/noticia/releases/em-duas-decada...
# 1   CGI.br Notícias  https://cgi.br/noticia/releases/no-fib-13-espe...
# 2   CGI.br Notícias  https://cgi.br/noticia/notas/mais-acessivel-e-...
# 3   CGI.br Notícias  https://cgi.br/noticia/releases/evento-em-sao-...
# 4   CGI.br Notícias  https://cgi.br/noticia/releases/abertas-as-ins...
# 5   CGI.br Notícias  https://cgi.br/noticia/releases/declaracao-fin...
# 6   CGI.br Notícias  https://cgi.br/noticia/notas/nota-de-falecimen...
# 7   CGI.br Notícias  https://cgi.br/noticia/notas/nota-de-falecimen...
# 8   CGI.br Notícias  https://cgi.br/noticia/releases/forum-da-inter...
# 9   CGI.br Notícias  https://cgi.br/noticia/releases/premio-destaqu...
# 10  CGI.br Notícias  https://cgi.br/noticia/releases/escola-de-gove...
# 11  CGI.br Notícias  https://cgi.br/noticia/notas/especialistas-int...
# 12  CGI.br Notícias  https://cgi.br/noticia/notas/nic-br-abre-chama...
# 13  CGI.br Notícias  https://cgi.br/noticia/releases/ix-br-atinge-n...
# 14  CGI.br Notícias  https://cgi.br/noticia/releases/ministra-da-ci...
# 15  CGI.br Notícias  https://cgi.br/noticia/releases/com-modelo-mul...
# 16  CGI.br Notícias  https://cgi.br/noticia/releases/cgi-br-lanca-p...
# 17  CGI.br Notícias  https://cgi.br/noticia/releases/uso-mais-plane...
# 18  CGI.br Notícias  https://cgi.br/noticia/releases/fasciculo-rede...
# 19  CGI.br Notícias  https://cgi.br/noticia/releases/hartmut-glaser...
#
#           source
# 0   CGI Notícias
# 1   CGI Notícias
# 2   CGI Notícias
# 3   CGI Notícias
# 4   CGI Notícias
# 5   CGI Notícias
# 6   CGI Notícias
# 7   CGI Notícias
# 8   CGI Notícias
# 9   CGI Notícias
# 10  CGI Notícias
# 11  CGI Notícias
# 12  CGI Notícias
# 13  CGI Notícias
# 14  CGI Notícias
# 15  CGI Notícias
# 16  CGI Notícias
# 17  CGI Notícias
# 18  CGI Notícias
# 19  CGI Notícias

# %%
def plot_charts(df):
    if df.empty:
        print("❌ Sem dados para plotar")
        return

    # Top 15
    top15 = df.head(15).copy()
    top15["rank"] = range(1, len(top15) + 1)

    fig1 = px.bar(
        top15,
        x="rank",
        y="title",
        orientation="h",
        title="Top 15 Notícias – Internet Governance"
    )
    fig1.update_layout(height=600)
    fig1.show()

    # Fonte
    source_count = df["source"].value_counts().reset_index()
    source_count.columns = ["source", "count"]

    fig2 = px.pie(
        source_count,
        names="source",
        values="count",
        title="Distribuição por Fonte"
    )
    fig2.show()

    # Palavras
    text = " ".join(df["title"].astype(str)).lower()
    words = re.findall(r"\b\w{4,}\b", text)

    word_freq = (
        pd.Series(words)
        .value_counts()
        .head(20)
        .reset_index()
    )
    word_freq.columns = ["palavra", "freq"]

    fig3 = px.treemap(
        word_freq,
        path=["palavra"],
        values="freq",
        title="Palavras mais frequentes nos títulos"
    )
    fig3.show()

# %%
plot_charts(df_db)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="92bc5203-82ea-4569-adfc-357bdf51d108" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("92bc5203-82ea-4569-adfc-357bdf51d108")) {                    Plotly.newPlot(                        "92bc5203-82ea-4569-adfc-357bdf51d108",                        [{"hovertemplate":"rank=%{x}\u003cbr\u003etitle=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsMDQ4P"},"xaxis":"x","y":["Em duas d\u00e9cadas, propor\u00e7\u00e3o de lares urbanos brasileiros com Internet passou de 13% para 85%, aponta TIC Domic\u00edlios 2024","No FIB13, especialistas apontam expectativas e preocupa\u00e7\u00f5es em rela\u00e7\u00e3o ao Pacto Digital Global, da ONU","Mais acess\u00edvel e completo: conhe\u00e7a o novo site do Cetic.br","Evento em S\u00e3o Paulo celebra 15 anos de SACI-Adm, refer\u00eancia na disputa de dom\u00ednios de Internet no Brasil","Abertas as inscri\u00e7\u00f5es para o 13\u00ba F\u00f3rum da Internet no Brasil","Declara\u00e7\u00e3o final do NETmundial+10 apresenta recomenda\u00e7\u00f5es para fortalecer a abordagem multissetorial","Nota de falecimento: Mariana Stanton","Nota de falecimento: Luiz Gonzaga Lauschner","F\u00f3rum da Internet no Brasil resgata legado da Eco92 e discute desafios da governan\u00e7a digital e ambiental","Pr\u00eamio Destaques homenageia 12 personalidades que contribu\u00edram com o desenvolvimento da Internet no pa\u00eds","Escola de Governan\u00e7a da Internet no Brasil abre inscri\u00e7\u00f5es para 3\u00aa edi\u00e7\u00e3o de curso EaD gratuito","Especialistas internacionais destacam os 20 anos da Parceria para Medi\u00e7\u00e3o das TIC para o Desenvolvimento","NIC.br abre chamada de trabalhos para o IX F\u00f3rum","IX.br atinge novo recorde, com 40 Tbit\u002fs de tr\u00e1fego agregado","Ministra da Ci\u00eancia, Tecnologia e Inova\u00e7\u00e3o refor\u00e7a defesa do multissetorialismo na governan\u00e7a do mundo digital"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="c99dab9c-c00b-4895-888d-5135efcfc81a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c99dab9c-c00b-4895-888d-5135efcfc81a")) {                    Plotly.newPlot(                        "c99dab9c-c00b-4895-888d-5135efcfc81a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"source=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["European Commission","CGI Not\u00edcias","Senado Federal","NIC Not\u00edcias","C\u00e2mara dos Deputados","CGI Reuni\u00f5es"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i2","bdata":"yQDIAGIAMgAyAAoA"},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d35dace2-b1b9-4ca4-941c-d01c7e63980d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d35dace2-b1b9-4ca4-941c-d01c7e63980d")) {                    Plotly.newPlot(                        "d35dace2-b1b9-4ca4-941c-d01c7e63980d",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003efreq=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["para","internet","brasil","sobre","digital","comiss\u00e3o","aprova","online","debate","projeto","europe","european","2025","mais","educa\u00e7\u00e3o","dados","lan\u00e7a","governan\u00e7a","anos","senado"],"labels":["para","internet","brasil","sobre","digital","comiss\u00e3o","aprova","online","debate","projeto","europe","european","2025","mais","educa\u00e7\u00e3o","dados","lan\u00e7a","governan\u00e7a","anos","senado"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":{"dtype":"f8","bdata":"AAAAAABAXEAAAAAAAEBSQAAAAAAAAExAAAAAAACARUAAAAAAAIBCQAAAAAAAgEBAAAAAAAAAPkAAAAAAAAA7QAAAAAAAADtAAAAAAAAAOEAAAAAAAAA3QAAAAAAAADZAAAAAAAAAMkAAAAAAAAAyQAAAAAAAADJAAAAAAAAAMUAAAAAAAAAxQAAAAAAAADFAAAAAAAAAMUAAAAAAAAAwQA=="},"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker ...
