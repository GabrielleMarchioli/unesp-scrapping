# %%
# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
from datetime import datetime
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook_connected"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

BASE_URL = "https://www12.senado.leg.br/noticias/ultimas"

print("Scraper Senado Notícias pronto!")
# Out:
# Scraper Senado Notícias pronto!

# %%
# %%
def montar_url(pagina):
    if pagina == 1:
        return BASE_URL
    return f"{BASE_URL}/{pagina}"

# %%
# %%
noticias = []
TOTAL_PAGES = 5

for pagina in range(TOTAL_PAGES, 0, -1):
    url = montar_url(pagina)
    print(f"Coletando página {pagina}: {url}")

    r = requests.get(url, headers=HEADERS, timeout=15)
    if r.status_code != 200:
        print("  Erro ao acessar página")
        continue

    soup = BeautifulSoup(r.text, "html.parser")

    lista = soup.find("ol", class_="lista-resultados")
    if not lista:
        print("  Nenhuma lista encontrada")
        continue

    itens = lista.find_all("li", recursive=False)
    print(f"  {len(itens)} notícias encontradas")

    for item in itens:
        titulo_tag = item.find("span", class_="eta")
        link_tag = item.find("a", href=True)
        data_tag = item.select_one("div.text-muted.normalis")

        img_tag = item.find("img")

        if not titulo_tag or not link_tag:
            continue

        link = link_tag["href"]
        if link.startswith("/"):
            link = "https://www12.senado.leg.br" + link

        noticias.append({
            "titulo": titulo_tag.get_text(strip=True),
            "data": data_tag.get_text(strip=True) if data_tag else "NA",
            "link": link,
            "imagem": img_tag["src"] if img_tag else "NA",
            "pagina": pagina,
            "fonte": "Agência Senado"
        })

    time.sleep(1)

print(f"\nTotal coletado: {len(noticias)} notícias")
# Out:
# Coletando página 5: https://www12.senado.leg.br/noticias/ultimas/5
#   20 notícias encontradas
# Coletando página 4: https://www12.senado.leg.br/noticias/ultimas/4
#   20 notícias encontradas
# Coletando página 3: https://www12.senado.leg.br/noticias/ultimas/3
#   20 notícias encontradas
# Coletando página 2: https://www12.senado.leg.br/noticias/ultimas/2
#   20 notícias encontradas
# Coletando página 1: https://www12.senado.leg.br/noticias/ultimas
#   20 notícias encontradas
#
# Total coletado: 98 notícias

# %%
# %%
df_senado = pd.DataFrame(noticias)
df_senado.head(10)
# Out:
#                                               titulo              data  \
# 0  Criação do Dia da Lei Seca em 19 de junho vai ...  11/12/2025 14h10
# 1           CCJ aprova Marco Legal da Cibersegurança  11/12/2025 14h06
# 2  ‘PL da Dosimetria’: Esperidião Amin quer entre...  11/12/2025 12h52
# 3  Congresso deve votar Orçamento de 2026 na próx...  11/12/2025 11h11
# 4  Transferência de profissionais ao Mais Médicos...  11/12/2025 10h06
# 5  Debatedores questionam regras para migração de...  11/12/2025 10h05
# 6  PL Antifacção: relator Alessandro Vieira expli...  11/12/2025 09h59
# 7  Dois projetos sobre direitos das pessoas autis...  11/12/2025 09h49
# 8  Plínio critica proposta de nova Lei de Impeach...  11/12/2025 09h09
# 9  PEC da polícia científica conclui primeiro tur...  10/12/2025 21h34
#
#                                                 link  \
# 0  https://www12.senado.leg.br/noticias/audios/20...
# 1  https://www12.senado.leg.br/noticias/audios/20...
# 2  https://www12.senado.leg.br/noticias/videos/20...
# 3  https://www12.senado.leg.br/noticias/materias/...
# 4  https://www12.senado.leg.br/noticias/videos/20...
# 5  https://www12.senado.leg.br/noticias/audios/20...
# 6  https://www12.senado.leg.br/noticias/audios/20...
# 7  https://www12.senado.leg.br/noticias/videos/20...
# 8  https://www12.senado.leg.br/noticias/materias/...
# 9  https://www12.senado.leg.br/noticias/materias/...
#
#                                               imagem  pagina           fonte
# 0                                                 NA       5  Agência Senado
# 1                                                 NA       5  Agência Senado
# 2  /noticias/videos/2025/12/2018pl-da-dosimetria2...       5  Agência Senado
# 3  /noticias/materias/2025/12/11/congresso-deve-v...       5  Agência Senado
# 4  /noticias/videos/2025/12/transferencia-de-prof...       5  Agência Senado
# 5  /noticias/audios/2025/12/debatedores-questiona...       5  Agência Senado
# 6  /noticias/audios/2025/12/pl-antifaccao-relator...       5  Agência Senado
# 7  /noticias/videos/2025/12/dois-projetos-sobre-d...       5  Agência Senado
# 8  /noticias/materias/2025/12/11/plinio-critica-p...       5  Agência Senado
# 9  /noticias/materias/2025/12/10/pec-da-policia-c...       5  Agência Senado

# %%
# %%
keywords = [
    "agro", "agricultura", "pecuária", "rural",
    "meio ambiente", "clima", "energia", "infraestrutura"
]

pattern = r"|".join(keywords)

df_filt = df_senado[
    df_senado["titulo"].str.contains(pattern, case=False, na=False, regex=True)
].copy()

print(f"{len(df_filt)} notícias filtradas (de {len(df_senado)})")
df_filt.head()
# Out:
# 3 notícias filtradas (de 98)
#                                                titulo              data  \
# 25  Novo prazo para regularização de imóvel rural ...  11/12/2025 17h39
# 64  Avança projeto que susta norma sobre prorrogaç...  16/12/2025 12h47
# 95  Suspensão de decreto federal sobre concessões ...  16/12/2025 14h28
#
#                                                  link  \
# 25  https://www12.senado.leg.br/noticias/materias/...
# 64  https://www12.senado.leg.br/noticias/materias/...
# 95  https://www12.senado.leg.br/noticias/audios/20...
#
#                                                imagem  pagina           fonte
# 25  /noticias/materias/2025/12/11/novo-prazo-para-...       4  Agência Senado
# 64  /noticias/materias/2025/12/16/avanca-projeto-q...       2  Agência Senado
# 95                                                 NA       1  Agência Senado

# %%
# %%
def plot_charts(df):
    if df.empty:
        print("Sem dados para gráficos")
        return

    # Top 15 notícias
    top15 = df.head(15).copy()
    top15["rank"] = range(1, len(top15) + 1)

    fig1 = px.bar(
        top15,
        x="rank",
        y="titulo",
        orientation="h",
        title="Top 15 Notícias – Senado (Filtro Agro)"
    )
    fig1.update_layout(height=600)
    fig1.show()

    # Nuvem de palavras
    text = " ".join(df["titulo"]).lower()
    words = re.findall(r"\b\w{4,}\b", text)

    if words:
        wc = pd.Series(words).value_counts().head(20).reset_index()
        wc.columns = ["palavra", "freq"]

        fig2 = px.treemap(
            wc,
            path=["palavra"],
            values="freq",
            title="Nuvem de Palavras – Senado"
        )
        fig2.show()

plot_charts(df_filt if not df_filt.empty else df_senado)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="b55f5e8b-a977-4369-b434-74f6ad290357" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b55f5e8b-a977-4369-b434-74f6ad290357")) {                    Plotly.newPlot(                        "b55f5e8b-a977-4369-b434-74f6ad290357",                        [{"hovertemplate":"rank=%{x}\u003cbr\u003etitulo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQID"},"xaxis":"x","y":["Novo prazo para regulariza\u00e7\u00e3o de im\u00f3vel rural em \u00e1rea de fronteira vai a san\u00e7\u00e3o","Avan\u00e7a projeto que susta norma sobre prorroga\u00e7\u00e3o de concess\u00f5es de energia","Suspens\u00e3o de decreto federal sobre concess\u00f5es de energia segue para a CCJ"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewi ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="66ea796e-70b7-4f81-98de-72205eebaea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("66ea796e-70b7-4f81-98de-72205eebaea6")) {                    Plotly.newPlot(                        "66ea796e-70b7-4f81-98de-72205eebaea6",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003efreq=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["para","energia","sobre","concess\u00f5es","novo","im\u00f3vel","regulariza\u00e7\u00e3o","prazo","rural","avan\u00e7a","\u00e1rea","fronteira","san\u00e7\u00e3o","norma","susta","projeto","prorroga\u00e7\u00e3o","suspens\u00e3o","decreto","federal"],"labels":["para","energia","sobre","concess\u00f5es","novo","im\u00f3vel","regulariza\u00e7\u00e3o","prazo","rural","avan\u00e7a","\u00e1rea","fronteira","san\u00e7\u00e3o","norma","susta","projeto","prorroga\u00e7\u00e3o","suspens\u00e3o","decreto","federal"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":{"dtype":"f8","bdata":"AAAAAAAAAEAAAAAAAAAAQAAAAAAAAABAAAAAAAAAAEAAAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPw=="},"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parc ...
